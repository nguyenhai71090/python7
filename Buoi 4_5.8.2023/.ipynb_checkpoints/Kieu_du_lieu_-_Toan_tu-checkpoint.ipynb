# %% [markdown]
# # Kieu du lieu

# %%
print("my name is") #interger
# Out:
# my name is

# %%
print(101) #float
# Out:
# 101

# %%
print(True) # boolean
print(False)
# Out:
# True
# False

# %% [markdown]
# # Toán tử

# %%
a=10
b=5
c=2.5
d="pyton"
e="Fundamental"

# %% [markdown]
# ## Toán tử cộng

# %%
print(a+b)
print(a+c)
# Out:
# 15
# 12.5

# %%
print(d+e)
# Out:
# pytonFundamental

# %%
print(a+True)
print(a+ False)
# Out:
# 11
# 10

# %% [markdown]
# ## Toán tử trừ

# %%
print(a-b)
# Out:
# 5

# %% [markdown]
# ## Toán tử nhân

# %%
print(a*b)
# Out:
# 50

# %%
print(5*d)
# Out:
# pytonpytonpytonpytonpyton

# %% [markdown]
# ## Toán tử chia

# %%
print(a/b)
# Out:
# 2.0

# %% [markdown]
# ## Chia lấy dư

# %%
print(b%2) # lay phan du
print(b//2) # Lay phan nguyen
# Out:
# 1
# 2

# %% [markdown]
# ## Lũy thừa

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# ## Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:3ba9d56c-8c51-4b34-9276-f6831d8a40fc.png)

# %% [markdown]
# ## Phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Toán tử logic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:d0309418-2038-466d-9959-e873fcadd78a.png)![image.png](attachment:48663193-6a23-4c86-8d4e-7438ce86014e.png)
